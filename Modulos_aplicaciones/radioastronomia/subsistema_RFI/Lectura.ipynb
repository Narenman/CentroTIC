# %%
import psycopg2
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import signal
#%matplotlib notebook
# %matplotlib inline

def promedio(espectro, nfft):
    K = int(len(espectro)/(nfft))
    x = numpy.zeros(nfft)
    for i in range(K):
        x = x + espectro[i*nfft:(i+1)*nfft]
    x = x/K
    x = numpy.concatenate((x[int(nfft/2):], x[:int(nfft/2)]))
    return x

# %%
x=numpy.fromfile('/home/uis-e3t/Escritorio/tono/logFFT',dtype=numpy.float32, count=-1, sep='')

# %%
y = promedio(x, 2048)

# %%
plt.plot(x[:2048])
plt.plot(y)

# %%
Y = numpy.concatenate((y[1024:], y[:1024]))

# %%
plt.plot(Y)

# %%
freq = numpy.arange(88,112,16)
print(freq)
# Out:
# [ 88 104]
